# %% [markdown]
# <a href="https://colab.research.google.com/github/Programapython/detector_osteoartritis/blob/main/practicas/unidad2/practica11/Practica_10_Representaci%C3%B3n_y_descripci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='blue'>PRACTICA PDI 10</font>

# %% [markdown]
# ### 1. Detección de contornos
#
# Detecte bordes en una imagen que tenga distitas formas

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# Cargar la imagen
image = cv2.imread("./img/formas.png")

# Convertimos a escala de grises
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Reduce el ruido
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Detectamos bordes
edges = cv2.Canny(blurred, 50, 150)

# Encontramos contornos
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Dibujamos los contornos en la imagen original
output_image = image.copy()
for contour in contours:
    epsilon = 0.02 * cv2.arcLength(contour, True)
    approx = cv2.approxPolyDP(contour, epsilon, True)
    cv2.drawContours(output_image, [approx], -1, (0, 255, 0), 3)

# Mostramos la imagen
plt.figure(figsize=(8, 8))
plt.imshow(output_image)
plt.axis("off")
plt.show()

# %%
#EJEMPLO
# Contruyendo una imagen
x, y = np.ogrid[-np.pi:np.pi:100j, -np.pi:np.pi:100j]
r = np.sin(np.exp((np.sin(x)**3 + np.cos(y)**2)))*255
r = np.uint8(r)

out = np.zeros((100,100,3), np.uint8)
out[...,0]=r
out[...,1]=r
out[...,2]=r

# Detectamos bordes
edges = cv2.Canny(out, 120, 130)

# Encontramos contornos
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Dibujamos los contornos en la imagen original
output_image = out.copy()
for contour in contours:
    epsilon = 0.02 * cv2.arcLength(contour, True)
    approx = cv2.approxPolyDP(contour, epsilon, True)
    cv2.drawContours(output_image, [approx], -1, (0, 255, 0), 1)

# Mostramos la imagen
plt.figure(figsize=(5, 5))
plt.imshow(output_image)
plt.axis("off")
plt.show()

# %% [markdown]
# ### 2. Suavizado de poligonos y aproximacion poligonal
# * aproxime un poligono para la figura "cordiode.tif"

# %%
#https://docs.opencv.org/3.4/dd/d49/tutorial_py_contour_features.html

# %%
#CONVEX HULL

# %%
#Circulo minimo de encierre

# %%
#Encajado con una elipse

# %% [markdown]
# ### 3. Obtención de descriptores de regiones
# * Obtenga las propiedades de region disponibles en OpenCv

# %%
# Out:
# 25.538787726159047
# El perimetro es: 777.7442942857742
# El area es: 23685.0 ó 23685.0
# La circularidad es: 25.538787726159047

# %%
#BOUNDING BOX


#Relación de aspecto  width/height


#Extension de la forma Area/Area bounding box
# Out:
# La relacion de aspecto es: 1.2567567567567568
# La extension es: 0.3823985275598179

# %%
#RECTANGULO MINIMO
# Out:
# La inclinacion de la elipse es: -36.869895935058594

# %%
#Area del Rectangulo mínimo
# Out:
# 30446.647982178256

# %%
#RECTANGULARIDAD
# Out:
# 0.777918147635295

# %%
#Convex hull


#Solidez = Area/ convex_hull_area
# Out:
# La solidez es: 0.9913567586798652

# %%
#Diametro equivalente a una circunferencia
# Out:
# El diametro del circulo con area equivalente es: 173.6567839649587

# %% [markdown]
# ### 4. Propiedades de conjuntos de figuras
# * Obtenga las propiedades de varias regiones en simultaneo

# %%
# Out:
# El numero de regiones es:  5

# %%
#Propiedades
momentos = []
perimetros = []
areas = []
circularidades = []
centroides = []
# Out:
# (80, 221)
# (279, 222)
# (480, 148)
# (103, 65)
# (287, 73)

# %%
#ETIQUETADO DE COMPONENTES

# %%
#ETIQUETANDO CON PROPIEDADES ESPECIFICAS

# %% [markdown]
# ### 5. Momentos invariantes de Hu
# A una imagen en escala de grises, rotela, escalela, trasladela y luego compruebe la invarianza de los momentos de Hu

# %%
#Escalado

# %%
#Traslación

# %%
#Rotación

# %% [markdown]
# ![img](https://www.learnopencv.com/wp-content/ql-cache/quicklatex.com-ad6bb406556f48905d6ed93c8f0fb224_l3.png)

# %%
#MOMENTOS DE HU
# Out:
# MOMENTOS INVARIANTES DE HU
#
# ORIGINAL:
# [2.889] [6.356] [11.547] [11.576] [23.258] [14.777] [23.322]
# ESCALADA:
# [2.888] [6.354] [11.549] [11.574] [23.258] [14.775] [23.319]
# ROTADA:
# [2.889] [6.355] [11.543] [11.57] [23.247] [14.771] [23.313]
# TRASLADADA:
# [2.889] [6.356] [11.547] [11.576] [23.258] [14.777] [23.322]

# %% [markdown]
# ### 6. Comparación de Contornos
# Compare la semejanza de las imagenes m1.png, m2,png y m3,png

# %%
img1 = cv2.imread('Imagenes/m1.png',0)
img2 = cv2.imread('Imagenes/m2.png',0)
img3 = cv2.imread('Imagenes/m3.png',0)

# %%
#https://docs.opencv.org/3.4/d3/dc0/group__imgproc__shape.html#gaf2b97a230b51856d09a2d934b78c015f
# Out:
# Diferencia de M1 con M1:   0.0
# Diferencia de M1 con M2:   0.4089956972265024
# Diferencia de M1 con M3:   3.202513551906698
